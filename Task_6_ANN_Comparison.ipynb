# %% [markdown]
# # Task 6 — ANN implementation and model comparison
#
# This notebook runs the complete analysis in `task6_ann_comparison.py`. The script loads the Breast Cancer Wisconsin dataset, creates a stratified 80/20 train/test split, standardizes features without data leakage, trains the required 16 → 8 → 1 Keras ANN for 50 epochs, plots accuracy and loss, and compares the ANN with Logistic Regression and Random Forest on the same test set.
#
# **Target labels:** 0 = malignant, 1 = benign.
#
# ## Setup
#
# Install the dependencies with `python -m pip install tensorflow scikit-learn pandas matplotlib`, then run this notebook from the repository folder.
#
# The run saves the training curves, confusion matrices, model comparison CSV, and ANN classification report beside the notebook.

# %%
# %run task6_ann_comparison.py
